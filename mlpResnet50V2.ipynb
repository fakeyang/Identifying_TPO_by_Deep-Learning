# %%
import models
import datasets
import os
import numpy as np
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet_v2 import preprocess_input as preprocess_inputV2

# %%
attributes_dir = os.path.join("../data/multi_data/tree_attributes.csv")
images_dir = os.path.join("../data/multi_data/tree_images")

# %%
# load CSV data
df=datasets.load_tree_attributes(attributes_dir)
# load image data
images=datasets.load_tree_images(df, images_dir)

# %%
mlpResnet50V2 = models.create_mlpresnet50v2(11, 124,124,3, optimizer='adam', loss='binary_crossentropy', 
                                           metrics=['accuracy'])

# %%
# preprocess image data to fit resnet model
image = preprocess_inputV2(images)

# %%
# Divided data into a training set and a test set in a ratio of 9:1 randomly
from sklearn.model_selection import train_test_split
split = train_test_split(df, image, test_size=0.1, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split
trainY= trainAttrX["TPO"]
testY = testAttrX["TPO"]
trainAttrX=trainAttrX.drop("TPO", axis=1).drop("ID", axis=1)
testAttrX=testAttrX.drop("TPO", axis=1).drop("ID", axis=1)

# %%
models.train_multimodel_with_cv(trainAttrX, trainImagesX, testAttrX, testImagesX, trainY, testY,
                                mlpResnet50V2, cross_validation=5, epochs=15, batch_size=32)
# Out:
# Train Model
# ==================================================
# Create Model
# ==================================================
# Cross Validation
# ==================================================
# Iteration= 1
# Epoch 1/15
# 1839/1839 [==============================] - 132s 68ms/step - loss: 0.5779 - accuracy: 0.7350 - val_loss: 0.4810 - val_accuracy: 0.7918
# Epoch 2/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.4225 - accuracy: 0.8249 - val_loss: 0.4806 - val_accuracy: 0.7637
# Epoch 3/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.3392 - accuracy: 0.8654 - val_loss: 0.3579 - val_accuracy: 0.8460
# Epoch 4/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.2725 - accuracy: 0.8968 - val_loss: 0.3565 - val_accuracy: 0.8498
# Epoch 5/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.2144 - accuracy: 0.9223 - val_loss: 0.3573 - val_accuracy: 0.8542
# Epoch 6/15
# 1839/1839 [==============================] - 120s 66ms/step - loss: 0.1645 - accuracy: 0.9447 - val_loss: 0.3812 - val_accuracy: 0.8526
# Epoch 7/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1306 - accuracy: 0.9575 - val_loss: 0.3980 - val_accuracy: 0.8530
# Epoch 8/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1063 - accuracy: 0.9664 - val_loss: 0.4301 - val_accuracy: 0.8452
# Epoch 9/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0866 - accuracy: 0.9744 - val_loss: 0.4816 - val_accuracy: 0.8391
# Epoch 10/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0724 - accuracy: 0.9800 - val_loss: 0.4737 - val_accuracy: 0.8488
# Epoch 11/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0662 - accuracy: 0.9811 - val_loss: 0.5340 - val_accuracy: 0.8384
# Val_Accuracy: 83.48%
#  Val_Loss: 43.02%
# ==================================================
# Iteration= 2
# Epoch 1/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.2076 - accuracy: 0.9260 - val_loss: 0.3550 - val_accuracy: 0.8549
# Epoch 2/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.1654 - accuracy: 0.9430 - val_loss: 0.3806 - val_accuracy: 0.8482
# Epoch 3/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.1315 - accuracy: 0.9568 - val_loss: 0.4186 - val_accuracy: 0.8505
# Epoch 4/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.1058 - accuracy: 0.9666 - val_loss: 0.4302 - val_accuracy: 0.8522
# Epoch 5/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0879 - accuracy: 0.9736 - val_loss: 0.4583 - val_accuracy: 0.8449
# Epoch 6/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0773 - accuracy: 0.9770 - val_loss: 0.4791 - val_accuracy: 0.8457
# Epoch 7/15
# 1839/1839 [==============================] - 120s 66ms/step - loss: 0.0668 - accuracy: 0.9807 - val_loss: 0.4796 - val_accuracy: 0.8528
# Epoch 8/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0602 - accuracy: 0.9826 - val_loss: 0.5148 - val_accuracy: 0.8416
# Val_Accuracy: 84.88%
#  Val_Loss: 43.95%
# ==================================================
# Iteration= 3
# Epoch 1/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1640 - accuracy: 0.9434 - val_loss: 0.3755 - val_accuracy: 0.8503
# Epoch 2/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.1295 - accuracy: 0.9572 - val_loss: 0.3863 - val_accuracy: 0.8530
# Epoch 3/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.1073 - accuracy: 0.9671 - val_loss: 0.4176 - val_accuracy: 0.8539
# Epoch 4/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0882 - accuracy: 0.9731 - val_loss: 0.4531 - val_accuracy: 0.8468
# Epoch 5/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0778 - accuracy: 0.9767 - val_loss: 0.4940 - val_accuracy: 0.8425
# Epoch 6/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0668 - accuracy: 0.9812 - val_loss: 0.5158 - val_accuracy: 0.8458
# Epoch 7/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0625 - accuracy: 0.9821 - val_loss: 0.4897 - val_accuracy: 0.8499
# Epoch 8/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0548 - accuracy: 0.9849 - val_loss: 0.4927 - val_accuracy: 0.8517
# Val_Accuracy: 84.92%
#  Val_Loss: 45.31%
# ==================================================
# Iteration= 4
# Epoch 1/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1313 - accuracy: 0.9561 - val_loss: 0.4315 - val_accuracy: 0.8407
# Epoch 2/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.1049 - accuracy: 0.9663 - val_loss: 0.4378 - val_accuracy: 0.8428
# Epoch 3/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0876 - accuracy: 0.9738 - val_loss: 0.4710 - val_accuracy: 0.8474
# Epoch 4/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0764 - accuracy: 0.9776 - val_loss: 0.4546 - val_accuracy: 0.8509
# Epoch 5/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0654 - accuracy: 0.9816 - val_loss: 0.5348 - val_accuracy: 0.8333
# Epoch 6/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0627 - accuracy: 0.9824 - val_loss: 0.4922 - val_accuracy: 0.8527
# Epoch 7/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0542 - accuracy: 0.9857 - val_loss: 0.5294 - val_accuracy: 0.8490
# Epoch 8/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0514 - accuracy: 0.9860 - val_loss: 0.5270 - val_accuracy: 0.8490
# Val_Accuracy: 84.57%
#  Val_Loss: 48.48%
# ==================================================
# Iteration= 5
# Epoch 1/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1085 - accuracy: 0.9646 - val_loss: 0.4248 - val_accuracy: 0.8496
# Epoch 2/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0870 - accuracy: 0.9736 - val_loss: 0.4983 - val_accuracy: 0.8494
# Epoch 3/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0754 - accuracy: 0.9779 - val_loss: 0.4757 - val_accuracy: 0.8487
# Epoch 4/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0663 - accuracy: 0.9809 - val_loss: 0.5217 - val_accuracy: 0.8365
# Epoch 5/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0597 - accuracy: 0.9836 - val_loss: 0.4796 - val_accuracy: 0.8513
# Epoch 6/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0553 - accuracy: 0.9842 - val_loss: 0.5123 - val_accuracy: 0.8511
# Epoch 7/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0495 - accuracy: 0.9866 - val_loss: 0.5671 - val_accuracy: 0.8394
# Epoch 8/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0477 - accuracy: 0.9873 - val_loss: 0.5398 - val_accuracy: 0.8500
# Val_Accuracy: 84.70%
#  Val_Loss: 50.24%
# CV_Accuracy:84.51%(+/- 0.53%)
#  CV_Loss:46.20%(+/- 2.74%)
#
# 256/256 [==============================] - 10s 38ms/step - loss: 0.4183 - accuracy: 0.8542
# evaluate accuracy: 85.42%
#  evaluate loss: 41.83%

# %%
y_prob = mlpResnet50V2.predict(x=[testAttrX,testImagesX])
models.auc_curve(testY, y_prob)
