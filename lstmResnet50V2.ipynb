# %%
import models
import datasets
import os
import numpy as np
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet_v2 import preprocess_input as preprocess_inputV2

# %%
attributes_dir = os.path.join("../data/multi_data/tree_attributes.csv")
images_dir = os.path.join("../data/multi_data/tree_images")

# %%
# load CSV data
df=datasets.load_tree_attributes(attributes_dir)
# load image data
img=datasets.load_tree_images(df, images_dir)

# %%
# preprocess image data to fit resnet model
image = preprocess_inputV2(img)

# %%
# Divided data into a training set and a test set in a ratio of 9:1 randomly
from sklearn.model_selection import train_test_split
split = train_test_split(df, image, test_size=0.1, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split
trainY= trainAttrX["TPO"]
testY = testAttrX["TPO"]
trainAttrX=trainAttrX.drop("TPO", axis=1).drop("ID", axis=1)
testAttrX=testAttrX.drop("TPO", axis=1).drop("ID", axis=1)
x_trainAttr = trainAttrX.to_numpy()
x_trainAttr= x_trainAttr.reshape(len(trainAttrX), 1, 11)
print("shape of train:{}".format(x_trainAttr.shape))
x_testAttr = testAttrX.to_numpy()
x_testAttr = x_testAttr.reshape(len(testAttrX), 1, 11)
print("shape of test:{}".format(x_testAttr.shape))
# Out:
# shape of train:(73551, 1, 11)
# shape of test:(8173, 1, 11)

# %%
lstmResnet50V2 = models.create_lstmresnet50v2(1, 11, 124,124,3, optimizer='adam', 
                                         loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
models.train_multimodel_with_cv(x_trainAttr, trainImagesX, x_testAttr, testImagesX, trainY, testY,
                               lstmResnet50V2, cross_validation=5, epochs=15, batch_size=32)
# Out:
# Train Model
# ==================================================
# Create Model
# ==================================================
# Cross Validation
# ==================================================
# Iteration= 1
# Epoch 1/15
# 1839/1839 [==============================] - 143s 68ms/step - loss: 0.5447 - accuracy: 0.7390 - val_loss: 0.4591 - val_accuracy: 0.7866
# Epoch 2/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.3705 - accuracy: 0.8385 - val_loss: 0.3446 - val_accuracy: 0.8486
# Epoch 3/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.3010 - accuracy: 0.8747 - val_loss: 0.3399 - val_accuracy: 0.8504
# Epoch 4/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.2506 - accuracy: 0.8994 - val_loss: 0.3510 - val_accuracy: 0.8478
# Epoch 5/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.1929 - accuracy: 0.9273 - val_loss: 0.3481 - val_accuracy: 0.8603
# Epoch 6/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1483 - accuracy: 0.9463 - val_loss: 0.3892 - val_accuracy: 0.8514
# Epoch 7/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1114 - accuracy: 0.9622 - val_loss: 0.4370 - val_accuracy: 0.8486
# Epoch 8/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0908 - accuracy: 0.9706 - val_loss: 0.4579 - val_accuracy: 0.8482
# Epoch 9/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0700 - accuracy: 0.9789 - val_loss: 0.5026 - val_accuracy: 0.8506
# Epoch 10/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0628 - accuracy: 0.9806 - val_loss: 0.5329 - val_accuracy: 0.8488
# Val_Accuracy: 84.41%
#  Val_Loss: 41.62%
# ==================================================
# Iteration= 2
# Epoch 1/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.2330 - accuracy: 0.9085 - val_loss: 0.3406 - val_accuracy: 0.8577
# Epoch 2/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1859 - accuracy: 0.9297 - val_loss: 0.3837 - val_accuracy: 0.8451
# Epoch 3/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1426 - accuracy: 0.9493 - val_loss: 0.4103 - val_accuracy: 0.8460
# Epoch 4/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.1092 - accuracy: 0.9618 - val_loss: 0.4297 - val_accuracy: 0.8523
# Epoch 5/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0848 - accuracy: 0.9721 - val_loss: 0.5142 - val_accuracy: 0.8388
# Epoch 6/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0726 - accuracy: 0.9766 - val_loss: 0.4925 - val_accuracy: 0.8471
# Epoch 7/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0608 - accuracy: 0.9808 - val_loss: 0.5252 - val_accuracy: 0.8506
# Epoch 8/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0548 - accuracy: 0.9822 - val_loss: 0.5281 - val_accuracy: 0.8529
# Val_Accuracy: 84.88%
#  Val_Loss: 45.30%
# ==================================================
# Iteration= 3
# Epoch 1/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.1813 - accuracy: 0.9317 - val_loss: 0.3616 - val_accuracy: 0.8606
# Epoch 2/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1422 - accuracy: 0.9490 - val_loss: 0.4052 - val_accuracy: 0.8526
# Epoch 3/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1098 - accuracy: 0.9621 - val_loss: 0.4139 - val_accuracy: 0.8576
# Epoch 4/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0867 - accuracy: 0.9713 - val_loss: 0.4983 - val_accuracy: 0.8466
# Epoch 5/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0731 - accuracy: 0.9768 - val_loss: 0.4763 - val_accuracy: 0.8505
# Epoch 6/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0601 - accuracy: 0.9819 - val_loss: 0.5322 - val_accuracy: 0.8475
# Epoch 7/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0543 - accuracy: 0.9831 - val_loss: 0.5119 - val_accuracy: 0.8526
# Epoch 8/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0502 - accuracy: 0.9847 - val_loss: 0.5233 - val_accuracy: 0.8578
# Val_Accuracy: 85.32%
#  Val_Loss: 46.53%
# ==================================================
# Iteration= 4
# Epoch 1/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.1438 - accuracy: 0.9476 - val_loss: 0.4016 - val_accuracy: 0.8496
# Epoch 2/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1071 - accuracy: 0.9636 - val_loss: 0.4223 - val_accuracy: 0.8545
# Epoch 3/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0708 - accuracy: 0.9771 - val_loss: 0.4848 - val_accuracy: 0.8493
# Epoch 5/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0622 - accuracy: 0.9802 - val_loss: 0.5200 - val_accuracy: 0.8467
# Epoch 6/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0520 - accuracy: 0.9839 - val_loss: 0.5370 - val_accuracy: 0.8517
# Epoch 7/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0470 - accuracy: 0.9856 - val_loss: 0.5409 - val_accuracy: 0.8526
# Epoch 8/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0425 - accuracy: 0.9870 - val_loss: 0.6051 - val_accuracy: 0.8447
# Val_Accuracy: 85.06%
#  Val_Loss: 49.59%
# ==================================================
# Iteration= 5
# Epoch 1/15
# 1839/1839 [==============================] - 123s 67ms/step - loss: 0.1125 - accuracy: 0.9609 - val_loss: 0.4517 - val_accuracy: 0.8463
# Epoch 2/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0860 - accuracy: 0.9717 - val_loss: 0.4921 - val_accuracy: 0.8514
# Epoch 3/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0695 - accuracy: 0.9777 - val_loss: 0.4989 - val_accuracy: 0.8490
# Epoch 4/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0601 - accuracy: 0.9811 - val_loss: 0.5226 - val_accuracy: 0.8474
# Epoch 5/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0530 - accuracy: 0.9838 - val_loss: 0.5466 - val_accuracy: 0.8507
# Epoch 6/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0454 - accuracy: 0.9859 - val_loss: 0.5768 - val_accuracy: 0.8430
# Epoch 7/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0451 - accuracy: 0.9864 - val_loss: 0.5727 - val_accuracy: 0.8489
# Epoch 8/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.0388 - accuracy: 0.9881 - val_loss: 0.5670 - val_accuracy: 0.8533
# Val_Accuracy: 84.88%
#  Val_Loss: 52.86%
# CV_Accuracy:84.91%(+/- 0.30%)
#  CV_Loss:47.18%(+/- 3.82%)
#
# 256/256 [==============================] - 10s 38ms/step - loss: 0.4212 - accuracy: 0.8557
# evaluate accuracy: 85.57%
#  evaluate loss: 42.12%

# %%
y_prob = lstmResnet50V2.predict(x=[x_testAttr,testImagesX])
models.auc_curve(testY, y_prob)
