# %%
import models
import datasets
import os
import numpy as np
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet_v2 import preprocess_input as preprocess_inputV2

# %%
attributes_dir = os.path.join("../data/multi_data/tree_attributes.csv")
images_dir = os.path.join("../data/multi_data/tree_images")

# %%
# load CSV data
df=datasets.load_tree_attributes(attributes_dir)
# load image data
images=datasets.load_tree_images(df, images_dir)

# %%
# create mlp resnet50 mixed model
mlpResnet50 = models.create_mlpresnet50(11, 124,124,3, optimizer='adam', loss='binary_crossentropy', 
                                        metrics=['accuracy'])

# %%
# preprocess image data to fit resnet model
image = preprocess_input(images)

# %%
# Divided data into a training set and a test set in a ratio of 9:1 randomly
from sklearn.model_selection import train_test_split
split = train_test_split(df, image, test_size=0.1, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split
trainY= trainAttrX["TPO"]
testY = testAttrX["TPO"]
trainAttrX=trainAttrX.drop("TPO", axis=1).drop("ID", axis=1)
testAttrX=testAttrX.drop("TPO", axis=1).drop("ID", axis=1)

# %%
models.train_multimodel_with_cv(trainAttrX, trainImagesX, testAttrX, testImagesX, trainY, testY,
                                mlpResnet50, cross_validation=5, epochs=15, batch_size=32)
# Out:
# Train Model
# ==================================================
# Create Model
# ==================================================
# Cross Validation
# ==================================================
# Iteration= 1
# Epoch 1/15
# 1839/1839 [==============================] - 128s 66ms/step - loss: 0.5055 - accuracy: 0.7620 - val_loss: 0.4009 - val_accuracy: 0.8249
# Epoch 2/15
# 1839/1839 [==============================] - 119s 65ms/step - loss: 0.3560 - accuracy: 0.8459 - val_loss: 0.3677 - val_accuracy: 0.8372
# Epoch 3/15
# 1839/1839 [==============================] - 119s 65ms/step - loss: 0.2850 - accuracy: 0.8826 - val_loss: 0.3304 - val_accuracy: 0.8522
# Epoch 4/15
# 1839/1839 [==============================] - 119s 65ms/step - loss: 0.2262 - accuracy: 0.9118 - val_loss: 0.5680 - val_accuracy: 0.8040
# Epoch 5/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.1786 - accuracy: 0.9341 - val_loss: 0.3426 - val_accuracy: 0.8596
# Epoch 6/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.1223 - accuracy: 0.9587 - val_loss: 0.4107 - val_accuracy: 0.8542
# Epoch 7/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.1156 - accuracy: 0.9625 - val_loss: 0.4179 - val_accuracy: 0.8543
# Epoch 8/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0747 - accuracy: 0.9780 - val_loss: 0.4355 - val_accuracy: 0.8600
# Epoch 9/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0619 - accuracy: 0.9820 - val_loss: 0.4555 - val_accuracy: 0.8643
# Epoch 10/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0526 - accuracy: 0.9844 - val_loss: 0.4645 - val_accuracy: 0.8651
# Val_Accuracy: 84.76%
#  Val_Loss: 41.94%
# ==================================================
# Iteration= 2
# Epoch 1/15
# 1839/1839 [==============================] - 119s 65ms/step - loss: 0.2195 - accuracy: 0.9164 - val_loss: 0.3635 - val_accuracy: 0.8547
# Epoch 2/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.1674 - accuracy: 0.9397 - val_loss: 0.3571 - val_accuracy: 0.8574
# Epoch 3/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.1238 - accuracy: 0.9575 - val_loss: 0.3660 - val_accuracy: 0.8647
# Epoch 4/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0920 - accuracy: 0.9704 - val_loss: 0.4308 - val_accuracy: 0.8513
# Epoch 5/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0790 - accuracy: 0.9764 - val_loss: 0.4330 - val_accuracy: 0.8613
# Epoch 6/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0634 - accuracy: 0.9804 - val_loss: 0.4589 - val_accuracy: 0.8633
# Epoch 7/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0537 - accuracy: 0.9855 - val_loss: 0.4929 - val_accuracy: 0.8596
# Epoch 8/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0538 - accuracy: 0.9840 - val_loss: 0.5047 - val_accuracy: 0.8560
# Epoch 9/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0392 - accuracy: 0.9891 - val_loss: 0.5600 - val_accuracy: 0.8523
# Val_Accuracy: 85.79%
#  Val_Loss: 44.08%
# ==================================================
# Iteration= 3
# Epoch 1/15
# 1839/1839 [==============================] - 119s 65ms/step - loss: 0.1304 - accuracy: 0.9559 - val_loss: 0.3813 - val_accuracy: 0.8547
# Epoch 2/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0896 - accuracy: 0.9708 - val_loss: 0.4124 - val_accuracy: 0.8606
# Epoch 3/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0703 - accuracy: 0.9783 - val_loss: 0.4647 - val_accuracy: 0.8589
# Epoch 4/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0636 - accuracy: 0.9809 - val_loss: 0.4527 - val_accuracy: 0.8629
# Epoch 5/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0547 - accuracy: 0.9842 - val_loss: 0.4997 - val_accuracy: 0.8572
# Epoch 6/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0467 - accuracy: 0.9860 - val_loss: 0.5019 - val_accuracy: 0.8636
# Epoch 7/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0401 - accuracy: 0.9887 - val_loss: 0.5549 - val_accuracy: 0.8522
# Epoch 8/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0377 - accuracy: 0.9885 - val_loss: 0.5363 - val_accuracy: 0.8597
# Val_Accuracy: 85.87%
#  Val_Loss: 47.55%
# ==================================================
# Iteration= 4
# Epoch 1/15
# 1839/1839 [==============================] - 119s 65ms/step - loss: 0.1003 - accuracy: 0.9669 - val_loss: 0.4073 - val_accuracy: 0.8583
# Epoch 2/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0705 - accuracy: 0.9778 - val_loss: 0.4366 - val_accuracy: 0.8628
# Epoch 3/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0585 - accuracy: 0.9822 - val_loss: 0.5025 - val_accuracy: 0.8506
# Epoch 4/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0492 - accuracy: 0.9854 - val_loss: 0.5184 - val_accuracy: 0.8579
# Epoch 5/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0462 - accuracy: 0.9865 - val_loss: 0.5827 - val_accuracy: 0.8495
# Epoch 6/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0425 - accuracy: 0.9873 - val_loss: 0.5073 - val_accuracy: 0.8637
# Epoch 7/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0356 - accuracy: 0.9895 - val_loss: 0.6127 - val_accuracy: 0.8467
# Epoch 8/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0329 - accuracy: 0.9904 - val_loss: 0.6150 - val_accuracy: 0.8547
# Val_Accuracy: 85.55%
#  Val_Loss: 52.28%
# ==================================================
# Iteration= 5
# Epoch 1/15
# 1839/1839 [==============================] - 119s 65ms/step - loss: 0.0797 - accuracy: 0.9744 - val_loss: 0.4194 - val_accuracy: 0.8636
# Epoch 2/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0568 - accuracy: 0.9830 - val_loss: 0.5594 - val_accuracy: 0.8493
# Epoch 3/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0554 - accuracy: 0.9835 - val_loss: 0.5328 - val_accuracy: 0.8512
# Epoch 4/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0424 - accuracy: 0.9875 - val_loss: 0.4914 - val_accuracy: 0.8632
# Epoch 5/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0410 - accuracy: 0.9880 - val_loss: 0.5282 - val_accuracy: 0.8580
# Epoch 6/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0389 - accuracy: 0.9886 - val_loss: 0.5150 - val_accuracy: 0.8645
# Epoch 7/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0357 - accuracy: 0.9902 - val_loss: 0.5459 - val_accuracy: 0.8604
# Epoch 8/15
# 1839/1839 [==============================] - 118s 64ms/step - loss: 0.0340 - accuracy: 0.9905 - val_loss: 0.5445 - val_accuracy: 0.8603
# Val_Accuracy: 85.88%
#  Val_Loss: 51.71%
# CV_Accuracy:85.57%(+/- 0.42%)
#  CV_Loss:47.51%(+/- 4.08%)
#
# 256/256 [==============================] - 10s 40ms/step - loss: 0.3915 - accuracy: 0.8732
# evaluate accuracy: 87.32%
#  evaluate loss: 39.15%

# %%
y_prob = mlpResnet50.predict(x=[testAttrX,testImagesX])
models.auc_curve(testY, y_prob)
