# %%
import models
import datasets
import os
import numpy as np
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications.resnet_v2 import preprocess_input as preprocess_inputV2

# %%
attributes_dir = os.path.join("../data/multi_data/tree_attributes.csv")
images_dir = os.path.join("../data/multi_data/tree_images")

# %%
# load CSV data
df=datasets.load_tree_attributes(attributes_dir)
# load image data
images=datasets.load_tree_images(df, images_dir)

# %%
# create mlp resnet50 mixed model
Resnet50V2 = models.create_resnet50v2(124,124,3, optimizer='adam', 
                                      loss='binary_crossentropy', metrics=['accuracy'])

# %%
# preprocess image data to fit resnet model
image = preprocess_inputV2(images)

# %%
# Divided data into a training set and a test set in a ratio of 9:1 randomly
from sklearn.model_selection import train_test_split
split = train_test_split(df, image, test_size=0.1, random_state=42)
(trainAttrX, testAttrX, trainImagesX, testImagesX) = split
trainY= trainAttrX["TPO"]
testY = testAttrX["TPO"]

# %%
models.train_model_with_cv(trainImagesX, testImagesX, trainY, testY,
                           Resnet50V2, cross_validation=5, epochs=15, batch_size=32)
# Out:
# Train Model
# ==================================================
# Create Model
# ==================================================
# Cross Validation
# ==================================================
# Iteration= 1
# Epoch 1/15
# 1839/1839 [==============================] - 124s 64ms/step - loss: 0.4322 - accuracy: 0.7892 - val_loss: 0.5174 - val_accuracy: 0.7769
# Epoch 2/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.3345 - accuracy: 0.8448 - val_loss: 0.3591 - val_accuracy: 0.8350
# Epoch 3/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.2772 - accuracy: 0.8739 - val_loss: 0.3679 - val_accuracy: 0.8335
# Epoch 4/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.2229 - accuracy: 0.9025 - val_loss: 0.3494 - val_accuracy: 0.8477
# Epoch 5/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1681 - accuracy: 0.9279 - val_loss: 0.4016 - val_accuracy: 0.8493
# Epoch 6/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1211 - accuracy: 0.9501 - val_loss: 0.4725 - val_accuracy: 0.8441
# Epoch 7/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0906 - accuracy: 0.9635 - val_loss: 0.5244 - val_accuracy: 0.8464
# Epoch 8/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0706 - accuracy: 0.9722 - val_loss: 0.6268 - val_accuracy: 0.8301
# Epoch 9/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0574 - accuracy: 0.9782 - val_loss: 0.6467 - val_accuracy: 0.8379
# Epoch 10/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0453 - accuracy: 0.9830 - val_loss: 0.6681 - val_accuracy: 0.8449
# Epoch 11/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0409 - accuracy: 0.9850 - val_loss: 0.7592 - val_accuracy: 0.8435
# Accuracy: 83.54%
# ==================================================
# Iteration= 2
# Epoch 1/15
# 1839/1839 [==============================] - 122s 66ms/step - loss: 0.1674 - accuracy: 0.9279 - val_loss: 0.4294 - val_accuracy: 0.8443
# Epoch 2/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1220 - accuracy: 0.9501 - val_loss: 0.4858 - val_accuracy: 0.8392
# Epoch 3/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0890 - accuracy: 0.9639 - val_loss: 0.5664 - val_accuracy: 0.8324
# Epoch 4/15
# 1839/1839 [==============================] - 120s 66ms/step - loss: 0.0694 - accuracy: 0.9726 - val_loss: 0.6266 - val_accuracy: 0.8231
# Epoch 5/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0536 - accuracy: 0.9796 - val_loss: 0.6406 - val_accuracy: 0.8431
# Epoch 6/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0469 - accuracy: 0.9828 - val_loss: 0.7388 - val_accuracy: 0.8424
# Epoch 7/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0394 - accuracy: 0.9852 - val_loss: 0.7574 - val_accuracy: 0.8450
# Epoch 8/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0378 - accuracy: 0.9866 - val_loss: 0.7765 - val_accuracy: 0.8327
# Accuracy: 83.78%
# ==================================================
# Iteration= 3
# Epoch 1/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1247 - accuracy: 0.9478 - val_loss: 0.4923 - val_accuracy: 0.8448
# Epoch 2/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0903 - accuracy: 0.9642 - val_loss: 0.5607 - val_accuracy: 0.8458
# Epoch 3/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0677 - accuracy: 0.9740 - val_loss: 0.5966 - val_accuracy: 0.8409
# Epoch 4/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0559 - accuracy: 0.9788 - val_loss: 0.6861 - val_accuracy: 0.8432
# Epoch 5/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0469 - accuracy: 0.9820 - val_loss: 0.6651 - val_accuracy: 0.8402
# Epoch 6/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0400 - accuracy: 0.9850 - val_loss: 0.7014 - val_accuracy: 0.8408
# Epoch 7/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0383 - accuracy: 0.9857 - val_loss: 0.8209 - val_accuracy: 0.8290
# Epoch 8/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0317 - accuracy: 0.9884 - val_loss: 0.8387 - val_accuracy: 0.8378
# Accuracy: 84.03%
# ==================================================
# Iteration= 4
# Epoch 1/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.1000 - accuracy: 0.9596 - val_loss: 0.5157 - val_accuracy: 0.8376
# Epoch 2/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0672 - accuracy: 0.9746 - val_loss: 0.6561 - val_accuracy: 0.8384
# Epoch 3/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0540 - accuracy: 0.9797 - val_loss: 0.6681 - val_accuracy: 0.8423
# Epoch 4/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0455 - accuracy: 0.9826 - val_loss: 0.7443 - val_accuracy: 0.8415
# Epoch 5/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0385 - accuracy: 0.9856 - val_loss: 0.7758 - val_accuracy: 0.8392
# Epoch 6/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0361 - accuracy: 0.9861 - val_loss: 0.8440 - val_accuracy: 0.8388
# Epoch 7/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0314 - accuracy: 0.9889 - val_loss: 0.7875 - val_accuracy: 0.8413
# Epoch 8/15
# 1839/1839 [==============================] - 120s 66ms/step - loss: 0.0284 - accuracy: 0.9895 - val_loss: 0.8325 - val_accuracy: 0.8428
# Accuracy: 84.02%
# ==================================================
# Iteration= 5
# Epoch 1/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0808 - accuracy: 0.9682 - val_loss: 0.6284 - val_accuracy: 0.8416
# Epoch 2/15
# 1839/1839 [==============================] - 121s 66ms/step - loss: 0.0557 - accuracy: 0.9790 - val_loss: 0.6531 - val_accuracy: 0.8348
# Epoch 3/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0441 - accuracy: 0.9837 - val_loss: 0.7075 - val_accuracy: 0.8454
# Epoch 4/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0386 - accuracy: 0.9856 - val_loss: 0.7433 - val_accuracy: 0.8347
# Epoch 5/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0333 - accuracy: 0.9876 - val_loss: 0.8073 - val_accuracy: 0.8468
# Epoch 6/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0304 - accuracy: 0.9886 - val_loss: 0.8883 - val_accuracy: 0.8365
# Epoch 7/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0270 - accuracy: 0.9903 - val_loss: 0.8500 - val_accuracy: 0.8350
# Epoch 8/15
# 1839/1839 [==============================] - 120s 65ms/step - loss: 0.0257 - accuracy: 0.9907 - val_loss: 0.8413 - val_accuracy: 0.8451
# Accuracy: 84.00%
# CV_Accuracy:83.87%(+/- 0.19%)
# 256/256 [==============================] - 10s 38ms/step - loss: 0.6080 - accuracy: 0.8493
# evaluate accuracy: 84.93%
#  evaluate loss: 60.80%

# %%
y_prob = Resnet50V2.predict(x=testImagesX)
models.auc_curve(testY, y_prob)
